# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sqlite3 as sql
import json
import yfinance as yf

# %%
conn = sql.connect('/content/nba_salary.sqlite')
conn

# %% [markdown]
# sqlite_master es la base de datos en donde queremos ver las tablas internas

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master where type='table'")

# %%
print(cursor. fetchall())
# Out:
# [('NBA_season1718_salary',), ('Seasons_Stats',)]

# %%
df_salary = pd.read_sql_query("select * from NBA_season1718_salary ", conn)
df_salary.head(20)
# Out:
#       X1             Player   Tm  season17_18
# 0    1.0      Stephen Curry  GSW   34682550.0
# 1    2.0       LeBron James  CLE   33285709.0
# 2    3.0       Paul Millsap  DEN   31269231.0
# 3    4.0     Gordon Hayward  BOS   29727900.0
# 4    5.0      Blake Griffin  DET   29512900.0
# 5    6.0         Kyle Lowry  TOR   28703704.0
# 6    7.0  Russell Westbrook  OKC   28530608.0
# 7    8.0        Mike Conley  MEM   28530608.0
# 8    9.0       James Harden  HOU   28299399.0
# 9   10.0      DeMar DeRozan  TOR   27739975.0
# 10  11.0         Al Horford  BOS   27734405.0
# 11  12.0    Carmelo Anthony  OKC   26243760.0
# 12  13.0     Damian Lillard  POR   26153057.0
# 13  14.0       Jrue Holiday  NOP   25686667.0
# 14  15.0         Chris Bosh  MIA   25289390.0
# 15  16.0       Kevin Durant  GSW   25000000.0
# 16  17.0        Otto Porter  WAS   24773250.0
# 17  18.0         Chris Paul  HOU   24599495.0
# 18  19.0      C.J. McCollum  POR   23962573.0
# ...

# %%
df_stats = pd.read_sql_query("select * from Seasons_Stats ", conn)
df_stats.head(20)
# Out:
#       X1    Year           Player  Pos   Age   Tm     G  GS  MP  PER  ...  \
# 0    0.0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  ...
# 1    1.0  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  ...
# 2    2.0  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  ...
# 3    3.0  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  ...
# 4    4.0  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  ...
# 5    5.0  1950.0       Ed Bartels    F  24.0  NYK   2.0 NaN NaN  NaN  ...
# 6    6.0  1950.0      Ralph Beard    G  22.0  INO  60.0 NaN NaN  NaN  ...
# 7    7.0  1950.0       Gene Berce  G-F  23.0  TRI   3.0 NaN NaN  NaN  ...
# 8    8.0  1950.0    Charlie Black  F-C  28.0  TOT  65.0 NaN NaN  NaN  ...
# 9    9.0  1950.0    Charlie Black  F-C  28.0  FTW  36.0 NaN NaN  NaN  ...
# 10  10.0  1950.0    Charlie Black  F-C  28.0  AND  29.0 NaN NaN  NaN  ...
# 11  11.0  1950.0      Nelson Bobb   PG  25.0  PHW  57.0 NaN NaN  NaN  ...
# ...

# %%
df = pd.read_json('https://raw.githubusercontent.com/BindiChen/machine-learning/master/data-analysis/027-pandas-convert-json/data/simple.json')

# %%
df
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
pfizer = yf.Ticker('PFE')

# %%
pfizer
# Out:
# yfinance.Ticker object <PFE>

# %%
pfizer.info
# Out:
# {'address1': '66 Hudson Boulevard East',
#  'city': 'New York',
#  'state': 'NY',
#  'zip': '10001-2192',
#  'country': 'United States',
#  'phone': '212 733 2323',
#  'website': 'https://www.pfizer.com',
#  'industry': 'Drug Manufacturers - General',
#  'industryKey': 'drug-manufacturers-general',
#  'industryDisp': 'Drug Manufacturers - General',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...
